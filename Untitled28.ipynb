# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\Rahul Awari\Downloads\Assignment\Product Launch Dataset.csv",encoding='latin-1')
df
# Out:
#           market_subcategory      id   eventdate        country  \
# 0          Other Soft Drinks       1  01-01-2005    Netherlands
# 1                 Carbonates       2  01-01-2005        Ireland
# 2       Juice & Juice Drinks       3  01-01-2005        Ireland
# 3       Juice & Juice Drinks       4  01-01-2005        Ireland
# 4       Juice & Juice Drinks       5  01-01-2005        Ireland
# ...                      ...     ...         ...            ...
# 114684     Other Soft Drinks  114685  01-10-2014  United States
# 114685     Other Soft Drinks  114686  01-10-2014  United States
# 114686              Iced Tea  114687  01-09-2014  United States
# 114687              Iced Tea  114688  01-09-2014  United States
# 114688         Energy Drinks  114689  01-10-2014  United States
#
#                                               positioning         region  \
# 0                                    Low Calorie, Natural    West Europe
# 1                               Convenience - Consumption    West Europe
# 2       100% Not from Concentrate, Convenience - Consu...    West Europe
# 3       100% Not from Concentrate, Convenience - Consu...    West Europe
# 4       100% Not from Concentrate, Convenience - Consu...    West Europe
# ...                                                   ...            ...
# 114684  Low Calorie, Energy/Alertness, Ethical - Packa...  North America
# 114685  Low Calorie, Energy/Alertness, Ethical - Packa...  North America
# 114686  Antioxidant, Natural, Ethical - Packaging, Con...  North America
# 114687  Antioxidant, Natural, Ethical - Packaging, Con...  North America
# 114688  Kosher, Juice Drinks (up to 25% juice), Allerg...  North America
#
#                                             flavor
# 0       Herbs, not specified; Fruit, not specified
# 1                             Fruit, not specified
# 2                             Lemon; Honey; Ginger
# 3                             Mango; Passion Fruit
# 4                                            Mango
# ...                                            ...
# 114684                            Berry, Wildberry
# 114685                    Raspberry, Not Specified
# 114686                                  Tea, White
# 114687           Tea, Green; Citrus, Not Specified
# 114688                       Cherry, Not Specified
#
# [114689 rows x 7 columns]

# %%
df['flavor']=df['flavor'].astype(str)
df
# Out:
#           market_subcategory      id   eventdate        country  \
# 0          Other Soft Drinks       1  01-01-2005    Netherlands
# 1                 Carbonates       2  01-01-2005        Ireland
# 2       Juice & Juice Drinks       3  01-01-2005        Ireland
# 3       Juice & Juice Drinks       4  01-01-2005        Ireland
# 4       Juice & Juice Drinks       5  01-01-2005        Ireland
# ...                      ...     ...         ...            ...
# 114684     Other Soft Drinks  114685  01-10-2014  United States
# 114685     Other Soft Drinks  114686  01-10-2014  United States
# 114686              Iced Tea  114687  01-09-2014  United States
# 114687              Iced Tea  114688  01-09-2014  United States
# 114688         Energy Drinks  114689  01-10-2014  United States
#
#                                               positioning         region  \
# 0                                    Low Calorie, Natural    West Europe
# 1                               Convenience - Consumption    West Europe
# 2       100% Not from Concentrate, Convenience - Consu...    West Europe
# 3       100% Not from Concentrate, Convenience - Consu...    West Europe
# 4       100% Not from Concentrate, Convenience - Consu...    West Europe
# ...                                                   ...            ...
# 114684  Low Calorie, Energy/Alertness, Ethical - Packa...  North America
# 114685  Low Calorie, Energy/Alertness, Ethical - Packa...  North America
# 114686  Antioxidant, Natural, Ethical - Packaging, Con...  North America
# 114687  Antioxidant, Natural, Ethical - Packaging, Con...  North America
# 114688  Kosher, Juice Drinks (up to 25% juice), Allerg...  North America
#
#                                             flavor
# 0       Herbs, not specified; Fruit, not specified
# 1                             Fruit, not specified
# 2                             Lemon; Honey; Ginger
# 3                             Mango; Passion Fruit
# 4                                            Mango
# ...                                            ...
# 114684                            Berry, Wildberry
# 114685                    Raspberry, Not Specified
# 114686                                  Tea, White
# 114687           Tea, Green; Citrus, Not Specified
# 114688                       Cherry, Not Specified
#
# [114689 rows x 7 columns]

# %%
df_fruit=pd.read_csv(r"C:\Users\Rahul Awari\Downloads\Assignment\Flavor Classification Dataset.csv",encoding='latin-1')
df_fruit
# Out:
#      Flavor_Group           flavor
# 0         Alcohol    Vodka, Citron
# 1         Alcohol          Bacardi
# 2         Alcohol    Bacardi, Gold
# 3         Alcohol  Bacardi, Silver
# 4         Alcohol        Beer, Ale
# ...           ...              ...
# 1440    Vegetable      Yam, Purple
# 1441    Vegetable  Yellow Wax Bean
# 1442    Vegetable             Yuca
# 1443    Vegetable            Yucca
# 1444    Vegetable         Zucchini
#
# [1445 rows x 2 columns]

# %%
dftemp=df_fruit[(df_fruit['Flavor_Group'] == "Fruit")]
dftemp['flavor'].astype(str)
dftemp
# Out:
#     Flavor_Group         flavor
# 516        Fruit           Abiu
# 517        Fruit           Akee
# 518        Fruit      Alibertia
# 519        Fruit      Aloe Vera
# 520        Fruit  Apple, Golden
# ..           ...            ...
# 776        Fruit      Wax Jambu
# 777        Fruit       Waxberry
# 778        Fruit   White Sapote
# 779        Fruit   Whortleberry
# 780        Fruit     Wood Apple
#
# [265 rows x 2 columns]

# %%
listfruit=dftemp['flavor'].tolist()
listfruit
# Out:
# ['Abiu',
#  'Akee',
#  'Alibertia',
#  'Aloe Vera',
#  'Apple, Golden',
#  'Apple, Granny smith',
#  'Apple, Green',
#  'Apple, Not specified',
#  'Apple, Red',
#  'Apricot',
#  'Araza',
#  'Bael Fruit',
#  'Banana',
#  'Barbados Cherry',
#  'Bayberry',
#  'Bayberry, Red',
#  'Bergamot',
#  'Berry, Aronia (Chokeberry)',
#  'Berry, Barberry',
#  'Berry, Bearberry',
#  'Berry, Blackberry',
#  'Berry, Blueberry',
#  'Berry, Boysenberry',
#  'Berry, Buffalo',
#  'Berry, Cranberry',
#  'Berry, Crowberry',
#  'Berry, Elderberry',
#  'Berry, Gooseberry',
#  'Berry, Hackberry',
#  'Berry, Lingon',
#  'Berry, Marion',
#  'Berry, Miracle',
#  'Berry, Mixed',
#  'Berry, Moringa',
#  'Berry, Nannyberry',
#  'Berry, Not specified',
#  'Berry, Red',
#  'Berry, Salmonberry',
#  'Berry, Strawberry Tree',
#  'Berry, Ugniberry',
#  'Berry, Wildberry',
#  'Berry, Wineberry',
#  'Bignay',
#  'Bilberry',
#  'Biriba',
#  'Black Sapote',
#  'Blackcurrant',
#  'Bluecurrant',
#  'Brambleberry',
#  'Cannonball',
#  'Canteloupe',
#  'Cassis',
#  'Ceylon Gooseberry',
#  'Champedak',
#  'Cherry Apple',
#  'Cherry, Beach',
#  'Cherry, Black',
#  'Cherry, Maraschino',
#  'Cherry, morello',
#  'Cherry, Not specified',
#  'Cherry, Red',
#  'Cherry, Sour',
#  'Cherry, Sweet',
#  'Cherry, Wild',
#  'Chinese Gooseberry',
#  'Chokeberry',
#  'Citrus, Not specified',
#  'Clementine',
#  'Coconut',
#  'Cowberry',
#  'Cupuacu',
#  'Currant, not specified',
#  'Date',
#  'Exotic Fruit, Not specified',
#  'Feijoa',
#  'Fig',
#  'Forest Fruit',
#  'Fruit, Camu Camu',
#  'Fruit, Doum Palm',
#  'Fruit, Not specified',
#  'Galanga',
#  'Gandara (Plum Mango)',
#  'Gandaria',
#  'Genipap',
#  'Giant Granadilla',
#  'Gourd, Bitter',
#  'Gourd, White',
#  'Grape, black',
#  'Grape, Green',
#  'Grape, Muscat',
#  'Grape, Not specified',
#  'Grape, Red',
#  'Grape, White',
#  'Grapefruit, Not specified',
#  'Grapefruit, Pink',
#  'Grapefruit, Red',
#  'Greengage',
#  'Grumichama',
#  'Guava',
#  'Heathberry',
#  'Honeydew',
#  'Huckleberry',
#  'Indian Jujube',
#  'Ita Palm',
#  'Jaboticaba',
#  'Jamaica Cherry',
#  'Kechapi',
#  'Kepel',
#  'Ketupa',
#  'Kiwano',
#  'Kiwi',
#  'Langsat/Duku',
#  'Lemon',
#  'Lemon, Bitter',
#  'Lemon-Lime',
#  'Lemonade',
#  'Lemonade, Pink',
#  'Lime',
#  'Lime, Key',
#  'Longan',
#  'Loquat',
#  'Lucmo',
#  'Lungan',
#  'Mabolo',
#  'Macapuno',
#  'Macis',
#  'Malaga',
#  'Malay Apple',
#  'Mamey Sapote',
#  'Mandarin',
#  'Mango',
#  'Mango, Green',
#  'Maprang',
#  'Margoline',
#  'Matrimony Vine',
#  'Medlar',
#  'Melon, Not specified',
#  'Minneola',
#  'Monkey Bread',
#  'Morinda',
#  'Naartjie',
#  'Nance',
#  'Nangka',
#  'Nashi Pear',
#  'Nata De Coco',
#  'Nectarine',
#  'Orange, Blood',
#  'Orange, Chinotto',
#  'Orange, Not specified',
#  'Orange, Ruby',
#  'Orange, Sicilian',
#  'Orange, Sweet',
#  'Orange, Valencia',
#  'Ortanique',
#  'Otaheite Gooseberry',
#  'Pandan',
#  'Papaya',
#  'Passion Fruit',
#  'Peach',
#  'Peach Palm',
#  'Peach, White',
#  'Pear',
#  'Persimmon',
#  'Philippine Roseapple',
#  'Physalis',
#  'Pineapple',
#  'Pineberry',
#  'Pitahaya',
#  'Pitanga',
#  'Plantain',
#  'Plum',
#  'Plum, Mirabelle',
#  'Prickly Pear',
#  'Prune',
#  'Pulasan',
#  'Raisin',
#  'Rambai',
#  'Rambutan',
#  'Raspberry, black',
#  'Raspberry, Blue',
#  'Raspberry, Not specified',
#  'Raspberry, Red',
#  'Redcurrant',
#  'Rhubarb',
#  'Rose Apple',
#  'Rosehip',
#  'Sala',
#  'Salak',
#  'Sansapote',
#  'Santoli',
#  'Sapodilla',
#  'Satsuma',
#  'Sea Grape',
#  'Shaddock',
#  'Sloeberry',
#  'Soncoya',
#  'Star Apple',
#  'Star Nut Palm',
#  'Strawberry',
#  'Sugar Apple',
#  'Sultana',
#  'Superfruit, Acai',
#  'Superfruit, Acerola',
#  'Superfruit, Agave',
#  'Superfruit, Baobab',
#  'Superfruit, Cactus',
#  'Superfruit, Caja',
#  'Superfruit, Calabash',
#  'Superfruit, Calamansi',
#  'Superfruit, Camu camu',
#  'Superfruit, Carambola',
#  'Superfruit, Cherimoya',
#  'Superfruit, Cloudberry',
#  'Superfruit, Custard Apple (Noi Naa)',
#  'Superfruit, Dragonfruit',
#  'Superfruit, Durian',
#  'Superfruit, Goji',
#  'Superfruit, Goldenberry',
#  'Superfruit, Gooseberry',
#  'Superfruit, Hawthorn',
#  'Superfruit, Hogplum',
#  'Superfruit, Jackfruit',
#  'Superfruit, Jujube',
#  'Superfruit, Komatsuna',
#  'Superfruit, Kumquat',
#  'Superfruit, Loganberry',
#  'Superfruit, Lucuma',
#  'Superfruit, Lychee',
#  'Superfruit, Mangosteen',
#  'Superfruit, Maqui (Chilean Wineberry)',
#  'Superfruit, Marula',
#  'Superfruit, Mulberry',
#  'Superfruit, Osmanthus',
#  'Superfruit, Pawpaw',
#  'Superfruit, Pomegranate',
#  'Superfruit, Pomelo',
#  'Superfruit, Quince',
#  'Superfruit, Seabuckthorn',
#  'Superfruit, Soursop & Guanabana',
#  'Superfruit, Starfruit',
#  'Superfruit, Umbu',
#  'Superfruit, Yacon',
#  'Superfruit, Yumberry',
#  'Superfruit, Yuzu',
#  'Surinam Cherry',
#  'Sweet Grenadilla',
#  'Sweetsop',
#  'Tamarillo',
#  'Tamarind',
#  'Tangelo',
#  'Tangerine',
#  'Tayberry',
#  'Temple Mandarin',
#  'Tree Tomato',
#  'Tropical Fruit, Not specified',
#  'Ube',
#  'Ugli',
#  'Voavanga',
#  'Water Apple\xa0',
#  'Watermelon',
#  'Wax Jambu',
#  'Waxberry',
#  'White Sapote',
#  'Whortleberry',
#  'Wood Apple']

# %%
df['eventdate']=pd.to_datetime(df['eventdate'])
df
# Out:
#           market_subcategory      id  eventdate        country  \
# 0          Other Soft Drinks       1 2005-01-01    Netherlands
# 1                 Carbonates       2 2005-01-01        Ireland
# 2       Juice & Juice Drinks       3 2005-01-01        Ireland
# 3       Juice & Juice Drinks       4 2005-01-01        Ireland
# 4       Juice & Juice Drinks       5 2005-01-01        Ireland
# ...                      ...     ...        ...            ...
# 114684     Other Soft Drinks  114685 2014-01-10  United States
# 114685     Other Soft Drinks  114686 2014-01-10  United States
# 114686              Iced Tea  114687 2014-01-09  United States
# 114687              Iced Tea  114688 2014-01-09  United States
# 114688         Energy Drinks  114689 2014-01-10  United States
#
#                                               positioning         region  \
# 0                                    Low Calorie, Natural    West Europe
# 1                               Convenience - Consumption    West Europe
# 2       100% Not from Concentrate, Convenience - Consu...    West Europe
# 3       100% Not from Concentrate, Convenience - Consu...    West Europe
# 4       100% Not from Concentrate, Convenience - Consu...    West Europe
# ...                                                   ...            ...
# 114684  Low Calorie, Energy/Alertness, Ethical - Packa...  North America
# 114685  Low Calorie, Energy/Alertness, Ethical - Packa...  North America
# 114686  Antioxidant, Natural, Ethical - Packaging, Con...  North America
# 114687  Antioxidant, Natural, Ethical - Packaging, Con...  North America
# 114688  Kosher, Juice Drinks (up to 25% juice), Allerg...  North America
#
#                                             flavor
# 0       Herbs, not specified; Fruit, not specified
# 1                             Fruit, not specified
# 2                             Lemon; Honey; Ginger
# 3                             Mango; Passion Fruit
# 4                                            Mango
# ...                                            ...
# 114684                            Berry, Wildberry
# 114685                    Raspberry, Not Specified
# 114686                                  Tea, White
# 114687           Tea, Green; Citrus, Not Specified
# 114688                       Cherry, Not Specified
#
# [114689 rows x 7 columns]

# %%
df['quarter']=df['eventdate'].dt.to_period('Q')

# %%
df
# Out:
#           market_subcategory      id  eventdate        country  \
# 0          Other Soft Drinks       1 2005-01-01    Netherlands
# 1                 Carbonates       2 2005-01-01        Ireland
# 2       Juice & Juice Drinks       3 2005-01-01        Ireland
# 3       Juice & Juice Drinks       4 2005-01-01        Ireland
# 4       Juice & Juice Drinks       5 2005-01-01        Ireland
# ...                      ...     ...        ...            ...
# 114684     Other Soft Drinks  114685 2014-01-10  United States
# 114685     Other Soft Drinks  114686 2014-01-10  United States
# 114686              Iced Tea  114687 2014-01-09  United States
# 114687              Iced Tea  114688 2014-01-09  United States
# 114688         Energy Drinks  114689 2014-01-10  United States
#
#                                               positioning         region  \
# 0                                    Low Calorie, Natural    West Europe
# 1                               Convenience - Consumption    West Europe
# 2       100% Not from Concentrate, Convenience - Consu...    West Europe
# 3       100% Not from Concentrate, Convenience - Consu...    West Europe
# 4       100% Not from Concentrate, Convenience - Consu...    West Europe
# ...                                                   ...            ...
# 114684  Low Calorie, Energy/Alertness, Ethical - Packa...  North America
# 114685  Low Calorie, Energy/Alertness, Ethical - Packa...  North America
# 114686  Antioxidant, Natural, Ethical - Packaging, Con...  North America
# 114687  Antioxidant, Natural, Ethical - Packaging, Con...  North America
# 114688  Kosher, Juice Drinks (up to 25% juice), Allerg...  North America
#
#                                             flavor quarter
# 0       Herbs, not specified; Fruit, not specified  2005Q1
# 1                             Fruit, not specified  2005Q1
# 2                             Lemon; Honey; Ginger  2005Q1
# 3                             Mango; Passion Fruit  2005Q1
# 4                                            Mango  2005Q1
# ...                                            ...     ...
# 114684                            Berry, Wildberry  2014Q1
# 114685                    Raspberry, Not Specified  2014Q1
# 114686                                  Tea, White  2014Q1
# 114687           Tea, Green; Citrus, Not Specified  2014Q1
# 114688                       Cherry, Not Specified  2014Q1
#
# [114689 rows x 8 columns]

# %%
listquarter=df['quarter'].unique()
listquarter
# Out:
# <PeriodArray>
# ['2005Q1', '2005Q3', '2009Q1', '2005Q4', '2006Q1', '2005Q2', '2008Q1',
#  '2007Q1', '2010Q1', '2011Q1', '2012Q1', '2013Q4', '2013Q1', '2013Q3',
#  '2014Q1', '2010Q3', '2010Q2']
# Length: 17, dtype: period[Q-DEC]

# %%
len(df[(df['quarter'] == listquarter[2]) & (df['flavor'].str.match(listfruit[3]))])
# Out:
# 47

# %%
df[(df['quarter'] == listquarter[2]) & (df['flavor'].str.match(listfruit[3]))
