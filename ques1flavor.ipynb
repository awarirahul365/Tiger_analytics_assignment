# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\Rahul Awari\Downloads\Assignment\Product Launch Dataset.csv",encoding='latin-1')
df
# Out:
#           market_subcategory      id   eventdate        country  \
# 0          Other Soft Drinks       1  01-01-2005    Netherlands
# 1                 Carbonates       2  01-01-2005        Ireland
# 2       Juice & Juice Drinks       3  01-01-2005        Ireland
# 3       Juice & Juice Drinks       4  01-01-2005        Ireland
# 4       Juice & Juice Drinks       5  01-01-2005        Ireland
# ...                      ...     ...         ...            ...
# 114684     Other Soft Drinks  114685  01-10-2014  United States
# 114685     Other Soft Drinks  114686  01-10-2014  United States
# 114686              Iced Tea  114687  01-09-2014  United States
# 114687              Iced Tea  114688  01-09-2014  United States
# 114688         Energy Drinks  114689  01-10-2014  United States
#
#                                               positioning         region  \
# 0                                    Low Calorie, Natural    West Europe
# ...

# %%
def func(df):
    df['flavor']=df['flavor'].astype(str)
    df.dropna(subset=['flavor'])
    len(df['flavor'])
    listflavor=[]
    for i in range(0,len(df['flavor'])):
        listflavor.append(df['flavor'][i])
    listtemp=[]
    for i in range(0,len(listflavor)):
        strtemp=listflavor[i].replace("||",";")
        listtemp.append(strtemp)
    setflavor=set([])
    for i in range(0,len(listtemp)):
        if listtemp[i]!="nan":
            str_ext=listtemp[i].split(";")
            for j in range(0,len(str_ext)):
                strlower=str_ext[j].lower()
                z=strlower.replace(" ","")
                setflavor.add(z)
            #str_ele=str_ext[j].split(',')
            #if len(str_ele)==1:
            #    setflavor.add(str_ele[0].lower())
            #else:
            #    str1=str_ele[0].lower()
            #    str2=str_ele[1].lower()
            #    if(str2 == " not specified"):
            #        setflavor.add(str1)
            #    else:
            #        setflavor.add(str2+str1)          
    return len(setflavor)

# %%
func(df)
# Out:
# 763

# %%
listcat=df['market_subcategory'].unique()
listcat
# Out:
# array(['Other Soft Drinks', 'Carbonates', 'Juice & Juice Drinks',
#        'Drink Concentrates & Mixes', 'Bottled Water - Flavoured',
#        'Energy Drinks', 'Iced Coffee', 'Iced Tea', 'Sports Drinks RTD',
#        'Bottled Water - Unflavoured', 'Sports Others', 'Sports Powders',
#        'Other Soft Drinks  ', 'Sports Supplements'], dtype=object)

# %%
subcatstring=""
val=0
for cat in listcat:
    df2=df[(df['market_subcategory']) == cat]
    df2['flavor']=df2['flavor'].astype(str)
    df2.dropna(subset=['flavor'])
    lf=[]
    for i in range(0,len(df2['flavor'])):
        lf.append(df['flavor'][i])
    lf2=[]
    for i in range(0,len(lf)):
        sttemp=lf[i].replace("||",";")
        lf2.append(sttemp)
    sflv=set([])
    for i in range(0,len(lf2)):
        if lf2[i]!="nan":
            stlist=lf2[i].split(';')
            for j in range(0,len(stlist)):
                slower=stlist[j].lower()
                zt=slower.replace(" ","")
                sflv.add(zt)
    if(len(sflv)>val):
        val=len(sflv)
        subcatstring=cat
subcatstring
# Out:
# C:\Users\RAHULA~1\AppData\Local\Temp/ipykernel_10616/595348946.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['flavor']=df2['flavor'].astype(str)
# 'Juice & Juice Drinks'
